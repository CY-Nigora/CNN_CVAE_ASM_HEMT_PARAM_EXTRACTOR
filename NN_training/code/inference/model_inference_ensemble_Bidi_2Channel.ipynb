# %%
# This file is part of the ADS Parameter Fitting project.
# must be used under ADS integrated Python env (A)
# namely, ..\ADS_install_path\tools\python\python.exe --> Python 3.13.2
# TODO: whole script is run in Jupyter because ADS python ADI only
# supports IPython kernel !!!

# packages to build DIR env
import os, json
# set ads dict: HPEESOF_DIR and home director : HOME
os.environ['HPEESOF_DIR'] = 'D:/ADS/install'
os.environ['HOME'] = 'D:/ADS/dir'

# # packages to multiprocessing
# # add current working directory
# import sys
# cur_path_nn = "E:/personal_Data/Document of School/Uni Stuttgart/Masterarbeit/Code/param_regression/ADS_Parameter_Fitting_local/IV_param_regression/NN_training"
# sys.path.append(cur_path_nn)

# packages to import ADS
from keysight.ads import de
from keysight.ads.de import db_uu as db
from keysight.edatoolbox import ads
import keysight.ads.dataset as dataset
from keysight.edatoolbox import util
from pathlib import Path
from IPython.core import getipython

# packages for model inference
from infer_sup_packg import *

import warnings
warnings.filterwarnings(
    "ignore",
    message="Conversion of an array with ndim > 0 to a scalar is deprecated"
)

# %%
# necessary class and functions for ADS simulation

class PyADS():
    def __init__(self):
        self.HPEESOF_DIR = 'D:/ADS/install'
        self.HOME = 'D:/ADS/dir'
        self.cur_workspace_path = None
        self.workspace = None
        self.cur_library_name = None
        self.library = None
        self.cur_design_name = None
        self.design = None

    def create_and_open_an_empty_workspace(self, workspace_path: str):
    # example : workspace_path = "C:/ADS_Python_Tutorials/tutorial1_wrk"
    # Ensure there isn't already a workspace open
        if de.workspace_is_open():
            de.close_workspace()
    
        # Cannot create a workspace if the directory already exists
        if os.path.exists(workspace_path):
            raise RuntimeError(f"Workspace directory already exists: {workspace_path}")
    
        # Create the workspace
        workspace = de.create_workspace(workspace_path)
        # Open the workspace
        workspace.open()
        # Return the open workspace and close when it finished
        return workspace
    
    def create_a_library_and_add_it_to_the_workspace(self, workspace: de.Workspace, library_name: str) -> None:
        #assert workspace.path is not None
        # Libraries can only be added to an open workspace
        assert workspace.is_open
        # We'll create a library in the directory of the workspace
        library_path = workspace.path / library_name
        # Create the library
        de.create_new_library(library_name, library_path)
        # And add it to the workspace (update lib.defs)
        workspace.add_library(library_name, library_path, de.LibraryMode.SHARED)
        lib=workspace.open_library(library_name,library_path,de.LibraryMode.SHARED)
        return lib

    # @timeout_thread_soft(20) # 20s timeout
    def schematic_simulation(self, workspace_path: str, library_name: str, design_name: str, instance_name: str, var_dict: dict, vgs_bias_param_sweep_name: str, vds_bias_param_sweep_name: str, vgs_bias_simulation_name: str, vds_bias_simulation_name: str, verilog_a_dir:str = None) -> None:
        ''' Load Path and files, Edit the design variables, Simulate the design, and return the dataset '''

        # test timeout
        # random_number = random.random()
        # time.sleep(13) if random_number >= 0.5 else time.sleep(0.5)

        # >> Load Path and files
        if not os.path.exists(workspace_path):
            raise RuntimeError(f"Workspace directory doesn't exist: {workspace_path}")
        if de.workspace_is_open():
            de.close_workspace()
        
        # Open the workspace
        # if (not self.workspace) or (self.cur_workspace_path != workspace_path):
        self.workspace = de.open_workspace(workspace_path)
        self.cur_workspace_path = workspace_path
        # Open the library
        # if (not self.library) or (self.cur_library_name != library_name):
        self.library = self.workspace.open_library(lib_name=library_name, mode=de.LibraryMode.SHARED)
        self.cur_library_name = library_name
        # Open the design
        # if (not self.design) or (self.cur_design_name != design_name):
        self.design = db.open_design((library_name, design_name, "schematic"), db.DesignMode.APPEND)
        self.cur_design_name = design_name

        # >> Edit the design variables
        # edit VAR
        v = self.design.get_instance(inst_name=instance_name)
        assert v.is_var_instance
        for var_name in var_dict:
            v.vars[var_name] = var_dict[var_name]
        # Save the design
        self.design.save_design()
        # Simulate the design
        output_dir = os.path.join(self.workspace.path, "output")
        netlist_file = os.path.join(output_dir, "data_gen.ckt")
        output_file =  os.path.join(output_dir, "data_gen.ckt.out")
        # create the simulation output directory
        util.safe_makedirs(output_dir)

        # >> Simulate and return the dataset
        # ipython = getipython.get_ipython()
        # if ipython is None:
        #     print("The remaining portion of the script must be run in an IPython environment. Exiting.")
        #     return
        # capture the netlist in a string
        netlist = self.design.generate_netlist()
        # access to the simulator object to run netlists
        simulator = ads.CircuitSimulator()
        # run the netlist, this will block output
        simulator.run_netlist(netlist, output_dir=output_dir, netlist_file=netlist_file, output_file=output_file, verilog_dir=verilog_a_dir)
        output_data = dataset.open(Path(os.path.join(output_dir, f"{design_name}.ds")))
        
        # >> return data in pandas DataFrame format
        # <class 'pandas.core.frame.DataFrame'>
        data_ids_vds = output_data[f'{vgs_bias_param_sweep_name}.{vgs_bias_simulation_name}.DC'].to_dataframe().reset_index()
        data_ids_vgs = output_data[f'{vds_bias_param_sweep_name}.{vds_bias_simulation_name}.DC'].to_dataframe().reset_index()
        return data_ids_vds, data_ids_vgs
    


    def dataset_reshape(self, pd_data_IV: pd.DataFrame, pd_data_gm: pd.DataFrame, IV_dimension: list, gm_dimension: list, var_dict: dict):
        ''' reshape the dataset into desired input matrix and output vector '''
        IV_row_count = IV_dimension[0] # Vgs
        IV_col_count = IV_dimension[1] # Vds
        gm_row_count = gm_dimension[0] # Vds
        gm_col_count = gm_dimension[1] # Vgs

        output_x_IV = np.empty((IV_row_count, IV_col_count),dtype=np.float64)
        output_x_gm = np.empty((gm_row_count, gm_col_count),dtype=np.float64)
        output_y = np.empty((len(var_dict), 1),dtype=np.float64)

        IV_row = pd_data_IV["VGS"].drop_duplicates().sort_values(ascending=True).tolist() # attention here: must be descending order
        gm_row = pd_data_gm["VDS"].drop_duplicates().sort_values(ascending=True).tolist()

        for index,row_value in enumerate(IV_row):
            output_x_IV[index, :] = pd_data_IV.loc[pd_data_IV['VGS'] == row_value, 'IDS.i'].to_numpy()
        for index,row_value in enumerate(gm_row):
            output_x_gm[index, :] = pd_data_gm.loc[pd_data_gm['VDS'] == row_value, 'IDS.i'].to_numpy()
        for index, item in enumerate(var_dict):
            output_y[index, 0] = var_dict[item]

        return output_x_IV, output_x_gm, output_y
    

def param_random_generator(param_range: dict):
    ''' generate a random parameter set for the HEMT model '''
    # define the parameter range
    # param_range = {
    #     'VOFF': (-1.2, 2.6),
    #     'U0': (0, 2.2),
    #     'NS0ACCS': (1e15, 1e20),
    #     'NFACTOR': (0.1, 5),
    #     'ETA0': (0, 1),
    #     'VSAT': (5e4, 1e7),
    #     'VDSCALE': (0.5, 1e6),
    #     'CDSCD': (1e-5, 0.75),
    #     'LAMBDA': (0, 0.2),
    #     'MEXPACCD': (0.05, 12),
    #     'DELTA': (2, 100)
    # }
    # generate random parameters
    var_dict = {key: str(np.random.uniform(low=val[0], high=val[1])) for key, val in param_range.items()}
    return var_dict

def init_h5_file(h5_path, x_iv_shape, x_gm_shape, y_shape,
                 dtype_x=np.float64, dtype_y=np.float64):
    with h5py.File(h5_path, 'w') as f:
        # X: [num_samples, m, n]
        f.create_dataset(
            'X_iv',
            shape=(0, x_iv_shape[0], x_iv_shape[1]),
            maxshape=(None, x_iv_shape[0], x_iv_shape[1]),
            dtype=dtype_x
        )
        f.create_dataset(
            'X_gm',
            shape=(0, x_gm_shape[0], x_gm_shape[1]),
            maxshape=(None, x_gm_shape[0], x_gm_shape[1]),
            dtype=dtype_x
        )
        # Y: [num_samples, y_len]
        f.create_dataset(
            'Y',
            shape=(0, y_shape[0], 1),
            maxshape=(None, y_shape[0], 1),
            dtype=dtype_y
        )

def append_to_h5(h5_path, x_iv_new, x_gm_new, y_new):
    x_iv_new = np.asarray(x_iv_new, dtype=np.float64)
    x_gm_new = np.asarray(x_gm_new, dtype=np.float64)
    y_new = np.asarray(y_new, dtype=np.float64)

    # 确保 y_new 是二维 (batch_size, y_len)
    if y_new.ndim == 2:
        y_new = y_new.reshape(-1, 1)
    else:
        raise RuntimeError(f"y_new must be vector, but got shape {y_new.shape}")

    with h5py.File(h5_path, 'a') as f:
        ds_x_iv = f['X_iv']
        ds_x_gm = f['X_gm']
        ds_y = f['Y']

        cur_len = ds_x_iv.shape[0]
        new_len = cur_len + 1

        # 扩展
        ds_x_iv.resize(new_len, axis=0)
        ds_x_gm.resize(new_len, axis=0)
        ds_y.resize(new_len, axis=0)

        # 赋值
        ds_x_iv[cur_len:new_len, :, :] = x_iv_new
        ds_x_gm[cur_len:new_len, :, :] = x_gm_new
        ds_y[cur_len:new_len, :, :] = y_new


def singel_process_iteration_data_gen2h5(workspace_path: str, 
                                         validate_dict: dict, 
                                         library_name: str, 
                                         design_name: str, 
                                         instance_name: str, 
                                         param_range: dict, 
                                         vgs_bias_param_sweep_name: str, 
                                         vds_bias_param_sweep_name: str, 
                                         vgs_bias_simulation_name: str, 
                                         vds_bias_simulation_name: str, 
                                         data_shape: list, 
                                         iteration_num: int, 
                                         process_id: int, 
                                         save_path: str, 
                                         verilog_a_dir: str = None, 
                                         new_start: bool = True, 
                                         old_stop_index: int = 0, 
                                         dtype_x=np.float64, dtype_y=np.float64):
    ''' generate dataset in single process iteration '''
    # create an instance of the PyADS class
    ads_ctrl = PyADS()
    X_iv_shape = data_shape[0]
    X_gm_shape = data_shape[1]
    Y_shape = data_shape[2]
    num_sampling = len(validate_dict['VSAT']) if type(validate_dict['VSAT'])!=str else 1
    iteration_num = num_sampling

    # init h5 file
    if new_start:
        init_h5_file(f"{save_path}\\validate.h5", X_iv_shape, X_gm_shape, Y_shape)
    # on cvae + rand mode, transform a big dict into several small dict available for iterator
    validate_dict_list = None
    if num_sampling != 1:
        validate_dict_list = [dict(zip(validate_dict.keys(), values)) for values in zip(*validate_dict.values())]

    for i in range(num_sampling) if new_start else range(old_stop_index, iteration_num):
        while True:
            try:
                start_time = time.time()
                if validate_dict:
                    var_dict = validate_dict if not validate_dict_list else validate_dict_list[i]
                else:
                # var_dict = param_random_generator(param_range)
                    var_dict = param_random_generator_log(param_range) # use log-uniform distribution based generator
                pd_data_vgs_bias, pd_data_gm = ads_ctrl.schematic_simulation(
                    workspace_path,
                    library_name,
                    design_name,
                    instance_name,
                    var_dict,
                    vgs_bias_param_sweep_name,
                    vds_bias_param_sweep_name,
                    vgs_bias_simulation_name,
                    vds_bias_simulation_name,
                    verilog_a_dir
                )
                X_iv, X_gm, y = ads_ctrl.dataset_reshape(pd_data_vgs_bias, pd_data_gm, X_iv_shape, X_gm_shape, var_dict)
                end_time = time.time()
                print(f" >> Process {process_id} :: Loop {i+1}/{iteration_num} :: used time: {round(end_time - start_time, 2)} s")
                try:
                    if not validate_dict:
                        append_to_h5(f"{save_path}\\dataset_process_{process_id}.h5", X_iv, X_gm, y)
                    else:
                        append_to_h5(f"{save_path}\\validate.h5", X_iv, X_gm, y)
                except:
                    print(f"【ERROR】Error appending data in process {process_id} at iteration {i + 1}")
                break

            # except TimeoutError:
            #     end_time = time.time()
            #     print(f' >> Process {process_id} :: Loop {i + 1}/{iteration_num} [Failed because Timeout] :: used time:', round(end_time - start_time, 2), 's', file=sys.stderr, flush=True)
            #     time.sleep(3)
            #     ads_ctrl.close()
            #     time.sleep(10)
            #     continue
            except:
                end_time = time.time()
                print(f' >> Process {process_id} :: Loop {i + 1}/{iteration_num} [Failed because cannot converge] :: used time:', round(end_time - start_time, 2), 's')
                time.sleep(1)
                # ads_ctrl.close()
                # time.sleep(2)
                continue

# %%
# For ADS
# DEFINE VARIABLES

workspace_path = "E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Simulation\\ADS\\GaN4EMoBiL_BiDi_GaN_wrk"
verilog_a_dir = workspace_path + "\\veriloga"
validate_dict = None
library_name = "GaN4EMoBiL_BiDi_GaN_lib"
design_name = "Optimizing_ADS_Bidi_Chenyan"
instance_name = "sweep_param"
var_dict_default = {'VOFF':'-4.1', 'U0':'0.4', 'NS0ACCS':'5e+16', 'NFACTOR':'0', 'ETA0':'1e-9', 'VSAT':'1.9e5', 'VDSCALE':'5', 'CDSCD':'0.05', 'LAMBDA':'0.01', 'MEXPACCD':'2', 'DELTA':'2'}
param_range = {
        'VOFF': (-4.7, -3),
        'U0': (0.1, 2.2),
        'NS0ACCS': (1e15, 1e20),
        'NFACTOR': (0, 10),
        'ETA0': (0, 1),
        'VSAT': (5e4, 1e7),
        'VDSCALE': (0.5, 1e6),
        'CDSCD': (0, 0.75),
        'LAMBDA': (0, 0.2),
        'MEXPACCD': (0, 12),
        'DELTA': (2, 100)
        # 'UA': (0, 1e-8),
        # 'UB': (0, 1e-16),
        # 'U0ACCS': (0.01, 0.4)
    }

X_iv_shape = [9,61]
X_gm_shape = [6,101]
Y_shape = [len(param_range),1]
X_iv_dict = {
    'goal': "X_iv",
    'row_range': (-10, -2),
    'col_range': (-1, 5),
    'row_num': X_iv_shape[0],
    'col_num': X_iv_shape[1]
}
X_gm_dict = {
    'goal': "X_gm",
    'row_range': (1, 6),
    'col_range': (-10, 0),
    'row_num': X_gm_shape[0],
    'col_num': X_gm_shape[1]
}


X_dict = {
    'X_iv': X_iv_dict,
    'X_gm': X_gm_dict
}
data_shape = [X_iv_shape, X_gm_shape, Y_shape]
vgs_bias_param_sweep_name = 'Sweep_vgs'
vds_bias_param_sweep_name = 'Sweep_vds'
vgs_bias_simulation_name = 'Output'
vds_bias_simulation_name = 'Transfer'
iteration_num = 1000
process_id = 1
data_save_path = "E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\temp_generated"


# ------------------------------------------------------------------
# For NN model inference

python_path = r"D:/Miniconda/envs/DL/python.exe"  # model based python path
script_dir  = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\code\\training\\cvae_Bidi_CNN" # path of code
# script_dir  = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\code\\training\\pure_MLP_Bidi" # baseline model
code_file_name = "main.py"
training_data_path   = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\training\\Bidi_merge_2Channel_mask1_11param.h5"  # path of training dataset

meas_path = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\training\\meas_smoothed_Bidi_2Channel.h5"

output_csv_path = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\temp_generated\\pred_7row.csv"

# %%
'''single model inference config'''

model_path = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\model\\cvae_Bidi_11param_2channel\\version_1_3"
# baseline
# model_path = r"E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\temp_Bidi_pureMLP_2channel\\version_1_1"

# basic params
inference_data_path = meas_path # path of inference dataset
# inference_data_path = training_data_path # path of inference dataset
inference_data_index = "None" #  from 0 to 9999            good case:(33, 666)
# "None"    : for 1. single input with shape (2,6,121)
#                 2. multile input with shaple (N,2,6,121)
# str(int)  : for single input with shape (N,2,6,121)
single_input_mode = bool(True)
cvae_ena = True
cvae_mode = 'rand'
num_sampling = 1000 # only used when cvae_mode = 'rand'
dropout_enale = False

# %%
'''single model inference processing ...'''

# Model inference
print(" >> Start model inference...")
# var_dict = model_inference(
#     python_path=python_path,
#     script_dir=script_dir,
#     code_file_name="asm_hemt_2stage_dnn.py" if not cvae_ena else "asm_hemt_cvae.py",
#     model_path=model_path,
#     inference_data_path=inference_data_path,
#     inference_data_index=inference_data_index,
#     output_csv_path=output_csv_path,
#     single_input_mode=single_input_mode,
#     cvae_ena=cvae_ena,
#     cvae_mode=cvae_mode,
#     num_sampling=num_sampling
# )
var_dict = model_inference(
    python_path=python_path,
    script_dir=script_dir,
    code_file_name=code_file_name,
    model_path=model_path,
    inference_data_path=inference_data_path,
    inference_data_index=inference_data_index,
    output_csv_path=output_csv_path,
    single_input_mode=single_input_mode,
    cvae_ena=cvae_ena,
    cvae_mode=cvae_mode,
    num_sampling=num_sampling,
    dropout_enable=dropout_enale,
)

# range correction
print(" >> Start output range correction...")
row_def = num_sampling if cvae_ena and cvae_mode=='rand' else 2
val_matrix = np.full((row_def, len(param_range)), 'OK', dtype="<U10")
var_matrix = np.full((row_def, len(param_range)), 0.0, dtype=np.float64)
for index,key in enumerate(param_range):
    var_matrix[:,index] = np.array(var_dict[key], dtype=float)
for col,key in enumerate(param_range):
    (low,high) = param_range[key]
    low_mask = var_matrix[:,col] < low
    high_mask = var_matrix[:,col] > high
    val_matrix[low_mask,col] = 'Underflow'
    var_matrix[low_mask,col] = low
    val_matrix[high_mask,col] = 'Overflow'
    var_matrix[high_mask,col] = high
    var_dict[key] = var_matrix[:,col].astype(str)
if ('Underflow' in val_matrix) or ('Overflow' in val_matrix):
    print('\t【VAL】Show the over-bounded matrix: \n', val_matrix)
else:
    print('\t【VAL】No element is over-bounded')

# print(var_dict)
    
# main function to run the data generation - single process
print(" >> Start validate in ADS...")
singel_process_iteration_data_gen2h5(
            workspace_path=workspace_path,
            validate_dict=var_dict,
            library_name=library_name,
            design_name=design_name,
            instance_name=instance_name,
            param_range=param_range,
            vgs_bias_param_sweep_name=vgs_bias_param_sweep_name,
            vds_bias_param_sweep_name=vds_bias_param_sweep_name,
            vgs_bias_simulation_name=vgs_bias_simulation_name,
            vds_bias_simulation_name=vds_bias_simulation_name,
            data_shape=data_shape,
            iteration_num=1,
            process_id=1,
            save_path=data_save_path,
            verilog_a_dir=verilog_a_dir)


# plot error between prediction and original I-V data
print(" >> Start plot error...")
best_idx_iv, best_idx_gm, best_idx_total = plot_error_2channel(inference_data_path, data_save_path, inference_data_index, var_dict, val_matrix, X_dict, output_csv_path)
best_idx_iv, best_idx_gm, best_idx_total = plot_error_2channel(inference_data_path, data_save_path, inference_data_index, var_dict, val_matrix, X_dict, output_csv_path, shrink=True, size=(10,4))

# fig 2 :: hist
if cvae_ena and cvae_mode == 'rand' and num_sampling > 1:
    odd = len(param_range)%2!=0
    size  = round((len(param_range))/2)
    fig, ax = plt.subplots(2, size, figsize=(20, 8)) 

    for index, key in enumerate(var_dict):
        data = list(map(float, var_dict[key]))
        kde = gaussian_kde(data)
        x_vals = np.linspace(min(data), max(data), 3000)
        y_vals = kde(x_vals)
        coordinate = [0, index] if ((index + 1) <= size) else [1, index - size]
        ax[coordinate[0], coordinate[1]].hist(data, bins = 30, density=True, color = 'grey', alpha = 0.6)
        ax[coordinate[0], coordinate[1]].set_title(key)
        ax[coordinate[0], coordinate[1]].plot(x_vals, y_vals, linewidth=2, label="KDE curve", color = 'red')
        ax[coordinate[0], coordinate[1]].grid(True, alpha=0.2)
        ax[coordinate[0], coordinate[1]].ticklabel_format(style='sci', scilimits=(-2,3), axis='x')
    if odd:
        fig.delaxes(ax[-1, -1])
    plt.tight_layout()
    fig.savefig("C:\\Users\\97427\\Desktop\\figure_hist.svg", bbox_inches='tight', format='svg')
    
# finnaly run the best inference case once again 
# in order to save correspondings param in ADS project file
if inference_data_index == "None":
    print('\n >> Save the best case in ADS project...')
    best_var_dict = {k: str(v[best_idx_total]) for k, v in var_dict.items()}
    singel_process_iteration_data_gen2h5(
                workspace_path=workspace_path,
                validate_dict=best_var_dict,
                library_name=library_name,
                design_name=design_name,
                instance_name=instance_name,
                param_range=param_range,
                vgs_bias_param_sweep_name=vgs_bias_param_sweep_name,
                vds_bias_param_sweep_name=vds_bias_param_sweep_name,
                vgs_bias_simulation_name=vgs_bias_simulation_name,
                vds_bias_simulation_name=vds_bias_simulation_name,
                data_shape=data_shape,
                iteration_num=1,
                process_id=1,
                save_path=data_save_path,
                verilog_a_dir=verilog_a_dir)

# {'VOFF':'1.785', 'U0':'0.424', 'NS0ACCS':'2e+17', 'NFACTOR':'1', 'ETA0':'0.06', 'VSAT':'8e+4', 'VDSCALE':'5', 'CDSCD':'0.1', 'LAMBDA':'0.01', 'MEXPACCD':'1.5', 'DELTA':'3'}
# Out:
#  >> Start model inference...
# [log] tee initialized at 2026-01-19 20:30:54 -> runs_dual\session_20260119-203054.log
# Using CUDA device 0: NVIDIA GeForce RTX 4060 Laptop GPU
#
# --- Solution Statistics (for first input) ---
#   VOFF     : mean=-4.16  std=0.01177
#   U0       : mean=0.2991  std=0.01969
#   NS0ACCS  : mean=5.52e+16  std=8.848e+15
#   NFACTOR  : mean=1.196  std=0.1503
#   ETA0     : mean=-0.01115  std=0.01772
#   VSAT     : mean=1.654e+05  std=1.7e+04
#   VDSCALE  : mean=179  std=126.5
#   CDSCD    : mean=0.08702  std=0.01965
#   LAMBDA   : mean=0.0422  std=0.003366
#   MEXPACCD : mean=2.624  std=0.1735
#   DELTA    : mean=12.36  std=1.278
#
# Saved all 1000 sampled solutions to E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\temp_generated\\pred_7row.csv
# Saved inferenced statistical feature to E:\\personal_Data\\Document of School\\Uni Stuttgart\\Masterarbeit\\Code\\param_regression\\ADS_Parameter_Fitting\\IV_param_regression\\NN_training\\dataset\\temp_generated\\pred_7row_mean_std.csv
#
#  >> Start output range correction...
# 	【VAL】Show the over-bounded matrix:
#  [['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']
#  ['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']
#  ['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']
#  ...
#  ['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']
#  ['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']
#  ['OK' 'OK' 'OK' ... 'OK' 'OK' 'OK']]
#  >> Start validate in ADS...
#  >> Process 1 :: Loop 1/1000 :: used time: 2.87 s
#  >> Process 1 :: Loop 2/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 3/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 4/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 5/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 6/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 7/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 8/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 9/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 10/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 11/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 12/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 13/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 14/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 15/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 16/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 17/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 18/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 19/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 20/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 21/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 22/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 23/1000 :: used time: 1.11 s
#  >> Process 1 :: Loop 24/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 25/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 26/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 27/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 28/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 29/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 30/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 31/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 32/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 33/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 34/1000 :: used time: 1.19 s
#  >> Process 1 :: Loop 35/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 36/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 37/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 38/1000 :: used time: 1.33 s
#  >> Process 1 :: Loop 39/1000 :: used time: 1.3 s
#  >> Process 1 :: Loop 40/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 41/1000 :: used time: 1.2 s
#  >> Process 1 :: Loop 42/1000 :: used time: 1.27 s
#  >> Process 1 :: Loop 43/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 44/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 45/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 46/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 47/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 48/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 49/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 50/1000 :: used time: 1.24 s
#  >> Process 1 :: Loop 51/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 52/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 53/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 54/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 55/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 56/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 57/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 58/1000 :: used time: 1.19 s
#  >> Process 1 :: Loop 59/1000 :: used time: 1.19 s
#  >> Process 1 :: Loop 60/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 61/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 62/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 63/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 64/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 65/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 66/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 67/1000 :: used time: 1.19 s
#  >> Process 1 :: Loop 68/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 69/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 70/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 71/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 72/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 73/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 74/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 75/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 76/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 77/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 78/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 79/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 80/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 81/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 82/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 83/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 84/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 85/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 86/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 87/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 88/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 89/1000 :: used time: 1.43 s
#  >> Process 1 :: Loop 90/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 91/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 92/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 93/1000 :: used time: 1.11 s
#  >> Process 1 :: Loop 94/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 95/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 96/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 97/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 98/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 99/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 100/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 101/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 102/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 103/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 104/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 105/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 106/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 107/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 108/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 109/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 110/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 111/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 112/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 113/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 114/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 115/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 116/1000 :: used time: 1.22 s
#  >> Process 1 :: Loop 117/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 118/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 119/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 120/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 121/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 122/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 123/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 124/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 125/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 126/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 127/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 128/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 129/1000 :: used time: 1.27 s
#  >> Process 1 :: Loop 130/1000 :: used time: 1.26 s
#  >> Process 1 :: Loop 131/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 132/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 133/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 134/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 135/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 136/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 137/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 138/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 139/1000 :: used time: 1.23 s
#  >> Process 1 :: Loop 140/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 141/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 142/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 143/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 144/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 145/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 146/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 147/1000 :: used time: 1.26 s
#  >> Process 1 :: Loop 148/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 149/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 150/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 151/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 152/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 153/1000 :: used time: 1.19 s
#  >> Process 1 :: Loop 154/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 155/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 156/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 157/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 158/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 159/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 160/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 161/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 162/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 163/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 164/1000 :: used time: 1.2 s
#  >> Process 1 :: Loop 165/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 166/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 167/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 168/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 169/1000 :: used time: 1.11 s
#  >> Process 1 :: Loop 170/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 171/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 172/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 173/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 174/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 175/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 176/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 177/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 178/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 179/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 180/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 181/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 182/1000 :: used time: 1.28 s
#  >> Process 1 :: Loop 183/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 184/1000 :: used time: 1.26 s
#  >> Process 1 :: Loop 185/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 186/1000 :: used time: 1.36 s
#  >> Process 1 :: Loop 187/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 188/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 189/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 190/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 191/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 192/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 193/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 194/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 195/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 196/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 197/1000 :: used time: 1.26 s
#  >> Process 1 :: Loop 198/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 199/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 200/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 201/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 202/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 203/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 204/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 205/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 206/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 207/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 208/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 209/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 210/1000 :: used time: 1.23 s
#  >> Process 1 :: Loop 211/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 212/1000 :: used time: 1.2 s
#  >> Process 1 :: Loop 213/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 214/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 215/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 216/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 217/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 218/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 219/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 220/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 221/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 222/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 223/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 224/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 225/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 226/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 227/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 228/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 229/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 230/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 231/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 232/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 233/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 234/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 235/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 236/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 237/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 238/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 239/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 240/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 241/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 242/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 243/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 244/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 245/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 246/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 247/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 248/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 249/1000 :: used time: 1.18 s
#  >> Process 1 :: Loop 250/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 251/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 252/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 253/1000 :: used time: 1.17 s
#  >> Process 1 :: Loop 254/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 255/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 256/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 257/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 258/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 259/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 260/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 261/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 262/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 263/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 264/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 265/1000 :: used time: 1.24 s
#  >> Process 1 :: Loop 266/1000 :: used time: 1.16 s
#  >> Process 1 :: Loop 267/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 268/1000 :: used time: 1.23 s
#  >> Process 1 :: Loop 269/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 270/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 271/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 272/1000 :: used time: 1.1 s
#  >> Process 1 :: Loop 273/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 274/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 275/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 276/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 277/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 278/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 279/1000 :: used time: 1.2 s
#  >> Process 1 :: Loop 280/1000 :: used time: 1.14 s
#  >> Process 1 :: Loop 281/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 282/1000 :: used time: 1.13 s
#  >> Process 1 :: Loop 283/1000 :: used time: 1.12 s
#  >> Process 1 :: Loop 284/1000 :: used time: 1.15 s
#  >> Process 1 :: Loop 285/1000 :: used time: 1.44 s
#  >> Process 1 :: Loop 286/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 287/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 288/1000 :: used time: 1.42 s
#  >> Process 1 :: Loop 289/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 290/1000 :: used time: 1.42 s
#  >> Process 1 :: Loop 291/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 292/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 293/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 294/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 295/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 296/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 297/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 298/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 299/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 300/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 301/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 302/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 303/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 304/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 305/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 306/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 307/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 308/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 309/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 310/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 311/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 312/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 313/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 314/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 315/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 316/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 317/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 318/1000 :: used time: 2.01 s
#  >> Process 1 :: Loop 319/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 320/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 321/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 322/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 323/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 324/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 325/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 326/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 327/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 328/1000 :: used time: 1.79 s
#  >> Process 1 :: Loop 329/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 330/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 331/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 332/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 333/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 334/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 335/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 336/1000 :: used time: 1.75 s
#  >> Process 1 :: Loop 337/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 338/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 339/1000 :: used time: 1.66 s
#  >> Process 1 :: Loop 340/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 341/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 342/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 343/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 344/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 345/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 346/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 347/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 348/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 349/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 350/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 351/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 352/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 353/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 354/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 355/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 356/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 357/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 358/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 359/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 360/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 361/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 362/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 363/1000 :: used time: 1.88 s
#  >> Process 1 :: Loop 364/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 365/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 366/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 367/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 368/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 369/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 370/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 371/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 372/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 373/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 374/1000 :: used time: 1.92 s
#  >> Process 1 :: Loop 375/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 376/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 377/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 378/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 379/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 380/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 381/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 382/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 383/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 384/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 385/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 386/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 387/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 388/1000 :: used time: 1.65 s
#  >> Process 1 :: Loop 389/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 390/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 391/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 392/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 393/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 394/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 395/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 396/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 397/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 398/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 399/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 400/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 401/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 402/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 403/1000 :: used time: 1.69 s
#  >> Process 1 :: Loop 404/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 405/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 406/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 407/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 408/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 409/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 410/1000 :: used time: 1.44 s
#  >> Process 1 :: Loop 411/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 412/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 413/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 414/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 415/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 416/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 417/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 418/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 419/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 420/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 421/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 422/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 423/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 424/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 425/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 426/1000 :: used time: 1.88 s
#  >> Process 1 :: Loop 427/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 428/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 429/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 430/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 431/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 432/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 433/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 434/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 435/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 436/1000 :: used time: 1.91 s
#  >> Process 1 :: Loop 437/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 438/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 439/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 440/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 441/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 442/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 443/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 444/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 445/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 446/1000 :: used time: 1.71 s
#  >> Process 1 :: Loop 447/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 448/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 449/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 450/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 451/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 452/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 453/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 454/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 455/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 456/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 457/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 458/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 459/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 460/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 461/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 462/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 463/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 464/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 465/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 466/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 467/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 468/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 469/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 470/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 471/1000 :: used time: 1.91 s
#  >> Process 1 :: Loop 472/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 473/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 474/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 475/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 476/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 477/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 478/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 479/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 480/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 481/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 482/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 483/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 484/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 485/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 486/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 487/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 488/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 489/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 490/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 491/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 492/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 493/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 494/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 495/1000 :: used time: 1.92 s
#  >> Process 1 :: Loop 496/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 497/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 498/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 499/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 500/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 501/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 502/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 503/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 504/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 505/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 506/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 507/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 508/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 509/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 510/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 511/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 512/1000 :: used time: 1.94 s
#  >> Process 1 :: Loop 513/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 514/1000 :: used time: 1.96 s
#  >> Process 1 :: Loop 515/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 516/1000 :: used time: 1.8 s
#  >> Process 1 :: Loop 517/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 518/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 519/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 520/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 521/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 522/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 523/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 524/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 525/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 526/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 527/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 528/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 529/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 530/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 531/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 532/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 533/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 534/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 535/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 536/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 537/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 538/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 539/1000 :: used time: 1.73 s
#  >> Process 1 :: Loop 540/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 541/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 542/1000 :: used time: 1.8 s
#  >> Process 1 :: Loop 543/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 544/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 545/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 546/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 547/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 548/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 549/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 550/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 551/1000 :: used time: 1.9 s
#  >> Process 1 :: Loop 552/1000 :: used time: 1.7 s
#  >> Process 1 :: Loop 553/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 554/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 555/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 556/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 557/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 558/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 559/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 560/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 561/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 562/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 563/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 564/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 565/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 566/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 567/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 568/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 569/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 570/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 571/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 572/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 573/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 574/1000 :: used time: 1.91 s
#  >> Process 1 :: Loop 575/1000 :: used time: 1.8 s
#  >> Process 1 :: Loop 576/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 577/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 578/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 579/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 580/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 581/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 582/1000 :: used time: 1.7 s
#  >> Process 1 :: Loop 583/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 584/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 585/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 586/1000 :: used time: 1.41 s
#  >> Process 1 :: Loop 587/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 588/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 589/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 590/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 591/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 592/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 593/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 594/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 595/1000 :: used time: 1.76 s
#  >> Process 1 :: Loop 596/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 597/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 598/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 599/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 600/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 601/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 602/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 603/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 604/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 605/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 606/1000 :: used time: 1.44 s
#  >> Process 1 :: Loop 607/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 608/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 609/1000 :: used time: 1.7 s
#  >> Process 1 :: Loop 610/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 611/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 612/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 613/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 614/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 615/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 616/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 617/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 618/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 619/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 620/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 621/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 622/1000 :: used time: 1.69 s
#  >> Process 1 :: Loop 623/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 624/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 625/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 626/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 627/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 628/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 629/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 630/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 631/1000 :: used time: 1.42 s
#  >> Process 1 :: Loop 632/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 633/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 634/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 635/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 636/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 637/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 638/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 639/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 640/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 641/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 642/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 643/1000 :: used time: 1.65 s
#  >> Process 1 :: Loop 644/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 645/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 646/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 647/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 648/1000 :: used time: 1.39 s
#  >> Process 1 :: Loop 649/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 650/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 651/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 652/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 653/1000 :: used time: 1.78 s
#  >> Process 1 :: Loop 654/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 655/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 656/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 657/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 658/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 659/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 660/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 661/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 662/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 663/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 664/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 665/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 666/1000 :: used time: 1.93 s
#  >> Process 1 :: Loop 667/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 668/1000 :: used time: 1.91 s
#  >> Process 1 :: Loop 669/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 670/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 671/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 672/1000 :: used time: 1.42 s
#  >> Process 1 :: Loop 673/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 674/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 675/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 676/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 677/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 678/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 679/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 680/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 681/1000 :: used time: 1.45 s
#  >> Process 1 :: Loop 682/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 683/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 684/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 685/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 686/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 687/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 688/1000 :: used time: 1.8 s
#  >> Process 1 :: Loop 689/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 690/1000 :: used time: 1.44 s
#  >> Process 1 :: Loop 691/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 692/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 693/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 694/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 695/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 696/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 697/1000 :: used time: 1.75 s
#  >> Process 1 :: Loop 698/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 699/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 700/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 701/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 702/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 703/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 704/1000 :: used time: 1.92 s
#  >> Process 1 :: Loop 705/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 706/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 707/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 708/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 709/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 710/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 711/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 712/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 713/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 714/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 715/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 716/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 717/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 718/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 719/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 720/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 721/1000 :: used time: 1.65 s
#  >> Process 1 :: Loop 722/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 723/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 724/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 725/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 726/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 727/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 728/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 729/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 730/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 731/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 732/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 733/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 734/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 735/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 736/1000 :: used time: 1.95 s
#  >> Process 1 :: Loop 737/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 738/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 739/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 740/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 741/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 742/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 743/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 744/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 745/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 746/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 747/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 748/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 749/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 750/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 751/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 752/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 753/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 754/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 755/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 756/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 757/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 758/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 759/1000 :: used time: 1.97 s
#  >> Process 1 :: Loop 760/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 761/1000 :: used time: 1.88 s
#  >> Process 1 :: Loop 762/1000 :: used time: 1.67 s
#  >> Process 1 :: Loop 763/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 764/1000 :: used time: 1.75 s
#  >> Process 1 :: Loop 765/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 766/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 767/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 768/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 769/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 770/1000 :: used time: 1.79 s
#  >> Process 1 :: Loop 771/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 772/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 773/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 774/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 775/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 776/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 777/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 778/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 779/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 780/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 781/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 782/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 783/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 784/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 785/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 786/1000 :: used time: 1.99 s
#  >> Process 1 :: Loop 787/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 788/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 789/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 790/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 791/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 792/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 793/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 794/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 795/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 796/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 797/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 798/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 799/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 800/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 801/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 802/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 803/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 804/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 805/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 806/1000 :: used time: 1.88 s
#  >> Process 1 :: Loop 807/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 808/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 809/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 810/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 811/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 812/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 813/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 814/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 815/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 816/1000 :: used time: 1.67 s
#  >> Process 1 :: Loop 817/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 818/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 819/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 820/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 821/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 822/1000 :: used time: 1.81 s
#  >> Process 1 :: Loop 823/1000 :: used time: 1.96 s
#  >> Process 1 :: Loop 824/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 825/1000 :: used time: 2.01 s
#  >> Process 1 :: Loop 826/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 827/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 828/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 829/1000 :: used time: 1.65 s
#  >> Process 1 :: Loop 830/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 831/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 832/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 833/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 834/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 835/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 836/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 837/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 838/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 839/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 840/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 841/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 842/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 843/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 844/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 845/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 846/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 847/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 848/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 849/1000 :: used time: 1.79 s
#  >> Process 1 :: Loop 850/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 851/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 852/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 853/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 854/1000 :: used time: 1.66 s
#  >> Process 1 :: Loop 855/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 856/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 857/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 858/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 859/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 860/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 861/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 862/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 863/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 864/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 865/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 866/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 867/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 868/1000 :: used time: 1.93 s
#  >> Process 1 :: Loop 869/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 870/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 871/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 872/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 873/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 874/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 875/1000 :: used time: 1.9 s
#  >> Process 1 :: Loop 876/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 877/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 878/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 879/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 880/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 881/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 882/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 883/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 884/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 885/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 886/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 887/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 888/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 889/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 890/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 891/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 892/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 893/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 894/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 895/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 896/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 897/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 898/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 899/1000 :: used time: 1.91 s
#  >> Process 1 :: Loop 900/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 901/1000 :: used time: 1.88 s
#  >> Process 1 :: Loop 902/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 903/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 904/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 905/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 906/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 907/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 908/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 909/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 910/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 911/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 912/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 913/1000 :: used time: 1.72 s
#  >> Process 1 :: Loop 914/1000 :: used time: 1.46 s
#  >> Process 1 :: Loop 915/1000 :: used time: 1.85 s
#  >> Process 1 :: Loop 916/1000 :: used time: 1.83 s
#  >> Process 1 :: Loop 917/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 918/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 919/1000 :: used time: 1.63 s
#  >> Process 1 :: Loop 920/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 921/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 922/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 923/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 924/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 925/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 926/1000 :: used time: 1.87 s
#  >> Process 1 :: Loop 927/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 928/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 929/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 930/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 931/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 932/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 933/1000 :: used time: 1.89 s
#  >> Process 1 :: Loop 934/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 935/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 936/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 937/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 938/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 939/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 940/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 941/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 942/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 943/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 944/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 945/1000 :: used time: 1.4 s
#  >> Process 1 :: Loop 946/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 947/1000 :: used time: 1.62 s
#  >> Process 1 :: Loop 948/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 949/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 950/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 951/1000 :: used time: 1.86 s
#  >> Process 1 :: Loop 952/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 953/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 954/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 955/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 956/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 957/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 958/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 959/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 960/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 961/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 962/1000 :: used time: 1.54 s
#  >> Process 1 :: Loop 963/1000 :: used time: 1.5 s
#  >> Process 1 :: Loop 964/1000 :: used time: 1.64 s
#  >> Process 1 :: Loop 965/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 966/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 967/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 968/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 969/1000 :: used time: 1.59 s
#  >> Process 1 :: Loop 970/1000 :: used time: 1.49 s
#  >> Process 1 :: Loop 971/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 972/1000 :: used time: 1.51 s
#  >> Process 1 :: Loop 973/1000 :: used time: 1.76 s
#  >> Process 1 :: Loop 974/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 975/1000 :: used time: 1.43 s
#  >> Process 1 :: Loop 976/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 977/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 978/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 979/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 980/1000 :: used time: 1.61 s
#  >> Process 1 :: Loop 981/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 982/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 983/1000 :: used time: 1.73 s
#  >> Process 1 :: Loop 984/1000 :: used time: 1.47 s
#  >> Process 1 :: Loop 985/1000 :: used time: 1.56 s
#  >> Process 1 :: Loop 986/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 987/1000 :: used time: 1.52 s
#  >> Process 1 :: Loop 988/1000 :: used time: 1.55 s
#  >> Process 1 :: Loop 989/1000 :: used time: 1.6 s
#  >> Process 1 :: Loop 990/1000 :: used time: 1.42 s
#  >> Process 1 :: Loop 991/1000 :: used time: 1.48 s
#  >> Process 1 :: Loop 992/1000 :: used time: 1.84 s
#  >> Process 1 :: Loop 993/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 994/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 995/1000 :: used time: 1.82 s
#  >> Process 1 :: Loop 996/1000 :: used time: 1.57 s
#  >> Process 1 :: Loop 997/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 998/1000 :: used time: 1.53 s
#  >> Process 1 :: Loop 999/1000 :: used time: 1.58 s
#  >> Process 1 :: Loop 1000/1000 :: used time: 1.53 s
#  >> Start plot error...
# e:\personal_Data\Document of School\Uni Stuttgart\Masterarbeit\Code\param_regression\ADS_Parameter_Fitting\IV_param_regression\NN_training\code\inference\infer_sup_packg.py:548: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[index][fig_col].legend()
# saved figure under path : C:\Users\97427\Desktop\figure_IV_full.svg
# saved figure under path : C:\Users\97427\Desktop\figure_IV_shrink.svg
#
#  >> Save the best case in ADS project...
#  >> Process 1 :: Loop 1/1 :: used time: 1.6 s

# %%
'''TTO inference processing ...'''

proxy_path = r"E:/personal_Data/Document of School/Uni Stuttgart/Masterarbeit/Code/param_regression/ADS_Parameter_Fitting/IV_param_regression/NN_training/temp_Bidi_cvae_11param_2channel/proxy_dual"

# TTO inference
var_dict = TTO_infer(
    python_path=python_path,
    script_dir=script_dir,
    code_file_name="infer_tto_strict.py",
    model_path=model_path,
    proxy_path=proxy_path,
    infer_data_path=inference_data_path,
    infer_data_index='None',
    steps=1000,
    lr=0.01
)

print(var_dict)


# range correction
print(" >> Start output range correction...")
row_def = 2 if cvae_ena and cvae_mode=='rand' else 1
val_matrix = np.full((row_def, len(param_range)), 'OK', dtype="<U10")
var_matrix = np.full((row_def, len(param_range)), 0.0, dtype=np.float64)
for index,key in enumerate(param_range):
    var_matrix[:,index] = np.array(var_dict[key], dtype=float)
for col,key in enumerate(param_range):
    (low,high) = param_range[key]
    low_mask = var_matrix[:,col] < low
    high_mask = var_matrix[:,col] > high
    val_matrix[low_mask,col] = 'Underflow'
    var_matrix[low_mask,col] = low
    val_matrix[high_mask,col] = 'Overflow'
    var_matrix[high_mask,col] = high
    var_dict[key] = var_matrix[:,col].astype(str)
if ('Underflow' in val_matrix) or ('Overflow' in val_matrix):
    print('\t【VAL】Show the over-bounded matrix: \n', val_matrix)
else:
    print('\t【VAL】No element is over-bounded')

print(var_dict)

# main function to run the data generation - single process
print(" >> Start validate in ADS...")
singel_process_iteration_data_gen2h5(
            workspace_path=workspace_path,
            validate_dict=var_dict,
            library_name=library_name,
            design_name=design_name,
            instance_name=instance_name,
            param_range=param_range,
            vgs_bias_param_sweep_name=vgs_bias_param_sweep_name,
            vds_bias_param_sweep_name=vds_bias_param_sweep_name,
            vgs_bias_simulation_name=vgs_bias_simulation_name,
            vds_bias_simulation_name=vds_bias_simulation_name,
            data_shape=data_shape,
            iteration_num=1,
            process_id=1,
            save_path=data_save_path,
            verilog_a_dir=verilog_a_dir)


# plot error between prediction and original I-V data
print(" >> Start plot error...")
best_idx_iv, best_idx_gm, best_idx_total = plot_error_2channel(inference_data_path, data_save_path, inference_data_index, var_dict, val_matrix, X_dict, output_csv_path)

# %%
# fig 2 :: hist
if cvae_ena and cvae_mode == 'rand' and num_sampling > 1:
    odd = len(param_range)%2!=0
    size  = round((len(param_range))/2)
    fig, ax = plt.subplots(2, size, figsize=(20, 8)) 

    for index, key in enumerate(var_dict):
        data = list(map(float, var_dict[key]))
        kde = gaussian_kde(data)
        x_vals = np.linspace(min(data), max(data), 3000)
        y_vals = kde(x_vals)
        coordinate = [0, index] if ((index + 1) <= size) else [1, index - size]
        ax[coordinate[0], coordinate[1]].hist(data, bins = 80, density=True, color = 'grey', alpha = 0.6)
        ax[coordinate[0], coordinate[1]].set_title(key)
        ax[coordinate[0], coordinate[1]].plot(x_vals, y_vals, linewidth=2, label="KDE curve", color = 'red')
        ax[coordinate[0], coordinate[1]].grid(True, alpha=0.2)
        ax[coordinate[0], coordinate[1]].ticklabel_format(style='sci', scilimits=(-2,3), axis='x')
    if odd:
        fig.delaxes(ax[-1, -1])
    plt.tight_layout()

# %%
# fig 3 :: better result representation


ref_Output = r"E:/personal_Data/Document of School/Uni Stuttgart/Masterarbeit/Code/param_regression/ADS_Parameter_Fitting/IV_param_regression/data_pre_processing/ref_data/meas_smoothed_Bidi_Output.h5"
ref_Transfer = r"E:/personal_Data/Document of School/Uni Stuttgart/Masterarbeit/Code/param_regression/ADS_Parameter_Fitting/IV_param_regression/data_pre_processing/ref_data/meas_smoothed_Bidi_Transfer.h5"
X_origin_o = h5py.File(ref_Output, 'r')
X_origin_t = h5py.File(ref_Transfer, 'r')
X_pred_mlp = h5py.File(f"{data_save_path}\\validate_bidi_mlp.h5", 'r')
X_pred = h5py.File(f"{data_save_path}\\validate.h5", 'r')
vgs_bias_x_axis = np.linspace(min(X_iv_dict['col_range']), max(X_iv_dict['col_range']), X_iv_dict['col_num'])
vds_bias_x_axis = np.linspace(min(X_gm_dict['col_range']), max(X_gm_dict['col_range']), X_gm_dict['col_num'])

four_fig_plot(X_origin_o, X_origin_t, X_pred, vgs_bias_x_axis, vds_bias_x_axis, size=(18,9))
# Out:
# size of measured Output feature:  (1, 9, 61)
# size of measured Transfer feature:  (1, 6, 101)
# size of predicted Output feature:  (1, 9, 61)
# size of predicted Transfer feature:  (1, 6, 101)
# saved figure under path : C:\Users\97427\Desktop\figure.svg

# %%
# fig 3.5 :: better result representation (mlp + cvae + meas)

four_fig_plus_mlp_plot(X_origin_o, X_origin_t, X_pred, X_pred_mlp, vgs_bias_x_axis, vds_bias_x_axis, size=(18,12), fontsize=16)
# Out:
# saved figure under path : C:\Users\97427\Desktop\figure.svg

# %%
# fig 4 :: better result representation (2 figure version)

two_fig_plot(X_origin_o, X_origin_t, X_pred, vgs_bias_x_axis, vds_bias_x_axis)
